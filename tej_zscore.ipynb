# %% [markdown]
# <a href="https://colab.research.google.com/github/fju155447/fin_data2/blob/main/tej_zscore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/fju155447/fin_data2/main/balance_sheet.csv"

# %%
df = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df
# Out:
#           YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 1101 TCC  2023/12        4             Y     12      NTD
# 1102 ACC  2023/12        4             Y     12      NTD
#
#          Total cash and cash equivalents  \
# CO_ID
# 1101 TCC                      66,366,622
# 1102 ACC                      33,229,516
#
#          Total current financial assets at fair value through profit or loss  \
# CO_ID
# 1101 TCC                                            727,762
# 1102 ACC                                         39,719,980
#
#          Financial assets at fair value through other comprehensive income - Current  \
# CO_ID
# 1101 TCC                                          6,972,790
# 1102 ACC                                          4,307,126
#
#          Financial assets measured at amortized cost - Current  \
# CO_ID
# 1101 TCC                                         34,236,957
# 1102 ACC                                         21,684,983
#
# ...
